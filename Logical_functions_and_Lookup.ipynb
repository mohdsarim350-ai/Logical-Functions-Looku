# %% [markdown]
# 1.
#
#   - Pass/Fail Formula.
#   - =If(B2>=40,"Pass","Fail")

# %% [markdown]
# 2.
#
#    - Bonus eligibility, Sales=B2, Attendance=C2
#
#    - =If(AND(B2>40000,C2>=90),"Bonus","No Bonus")

# %% [markdown]
# 3.
#
#    - Nested IF - Grades
#
#    - =IF(B2>=90,"A",IF(B2>=75,"B",IF(B2>=50,"C","Fail")))

# %% [markdown]
# 4.
#
#    - Department of EmplD = E103 (LOOKUP explanation)
#
#    - Formula (VLOOKUP used becaue EmplD is in first column):
#
#    - =VLOOKUP("E103",A2:C5,3,FALSE)
#
#    - Department = Finance
#
#    - Why VLOOKUP?
#
#    - EmplD is in first column
#
#    - Department is on right side
#
#    - Needs Exact match (FALSE)

# %% [markdown]
# 5.
#
#    - Commision Rate using VLOOKUP (Sales = 45,000)
#
#    - Table range = A2:B5
#
#    - =VLOOKUP(45000,A2:B5,2,TRUE)
#
#    - Commision = 10%
#
#    - Match is Approximate so it's TRUE

# %% [markdown]
# 6.
#
#    - Leace Exceeded Check
#
#    - Condition:
#
#    - Leaves Taken> Leaves Allowed --> "Exceeded"
#
#    - Else -> "OK"
#
#    - Leaves Taken = B2, Allowed = C2
#
#    - =IF(B2>C2,"Exceeded","OK")

# %% [markdown]
# 7.
#
#    - Salary of EmplD = E105 (INDEX-MATCH)
#
#    - =INDEX(B2:B5,MATCH("E105",A2:A5,0))
#
#    - Salary= 72,000

# %% [markdown]
# 8.
#
#    - Departmen of EmplD = E303 (XLOOKUP)
#
#    - =XLOOKUP("E303",A2:A5,B2:B5)
#
#    - Department = IT
